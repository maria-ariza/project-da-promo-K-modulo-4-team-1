# %% [markdown]
# # **Clasificación de profesiones por sector**

# %% [markdown]
# 1. Tecnología e Ingeniería
#
# 'Software Developer'
# 'Web Developer'
# 'Software Engineer'
# 'Technology Analyst'
# 'App Developer'
# 'System Developer'
# 'Mechanical Engineer'
# 'Technical Software Architect'
# 'Android Developer'
# 'IT Engineer'
# 'Software Engineering Manager'
# 'Senior Software Engineer'
# 'DevOps Engineer'
# 'Data Analyst & Developer'
# 'Cyber Security Technician'
# 'Machine Learning Engineer'
# 'Automation Systems Analyst'
# 'Robotics Engineer'
# 'IT Specialist for System Integration'
# 'IT Helpdesk Engineer'
# 'System Engineer'
#
# 2. Salud y Medicina
#
# 'Physician'
# 'Medical Care Technician'
# 'Med Student'
# 'Clinical Social Worker'
# 'Radiology Researcher'
# 'Therapist'
# 'Medicinal Chemist'
# 'Speech Pathologist'
# 'CNA (Certified Nursing Assistant)'
# 'Surgery Dept'
#
# 3. Investigación y Ciencia
#
# 'Research Assistant'
# 'Scientist'
# 'Chemist'
# 'Environmental Science Student'
# 'Researcher'
# 'Graduate Research Assistant'
# 'PhD Chemist'
#
# 4. Negocios, financas y legal
#
# 'CEO'
# 'Partner'
# 'Manager'
# 'Accountant'
# 'Business Analyst'
# 'Financial Tech'
# 'Hedge Fund Quant Trader'
# 'Project Manager'
# 'Content Marketing Consultant'
# 'Paralegal'
# 'Consultant'
#
# 5. Educación
#
#
# 'Teacher'
#
#
# 6. Diseño, Arte y Creatividad
#
# 'Product Designer'
# 'Graphiste Motion Designer'
# 'Editor'
# 'Concept Artist'
# 'Graphic Designer'
# ''Technical Artist'
# 'Environment Artist'
# 'Digital Project Manager'
# 'UX Designer'
# 'Writer'
#
# 7. Construcción y Manufactura
#
# 'Civil Engineer'
# 'Plant Mechanic'
# 'Truss Designer'
# 'Industrial Designer Intern'
# 'Electrician'
# 'Master Mechanic'
#
# 8. Servicios Generales
#
# 'Barista'
# 'Server'
# 'Dog Walker'
# 'Retail Worker'
# 'Driver'
#
# 9. Estudiante
#
# 'Student'
# 'Grad Student'
# 'History Student'
# 'Law Student'
# 'Master's Student in Computer Science'
# 'Industrial Engineering Student'
#
# 10. Emprendedores
#
# 'Entrepreneur'

# %% [markdown]
# IF [Job Title] = 'Software Developer' OR [Job Title] =
# 'Web Developer' OR [Job Title] =
# 'Software Engineer' OR [Job Title] =
# 'Technology Analyst' OR [Job Title] =
# 'App Developer' OR [Job Title] =
# 'System Developer' OR [Job Title] =
# 'Mechanical Engineer' OR [Job Title] =
# 'Technical Software Architect' OR [Job Title] =
# 'Android Developer' OR [Job Title] =
# 'IT Engineer' OR [Job Title] =
# 'Software Engineering Manager' OR [Job Title] =
# 'Senior Software Engineer' OR [Job Title] =
# 'DevOps Engineer' OR [Job Title] =
# 'Data Analyst & Developer' OR [Job Title] =
# 'Cyber Security Technician' OR [Job Title] =
# 'Machine Learning Engineer' OR [Job Title] =
# 'Automation Systems Analyst' OR [Job Title] =
# 'Robotics Engineer' OR [Job Title] =
# 'IT Specialist for System Integration' OR [Job Title] =
# 'IT Helpdesk Engineer' OR [Job Title] =
# 'System Engineer' THEN 'Tecnología e Ingeniería'
