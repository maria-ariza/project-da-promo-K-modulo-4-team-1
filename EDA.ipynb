# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df = pd.read_csv('files/Tinder_Data_v3_Clean_Edition.csv')

# %%
df.head(2)
# Out:
#                                 _id  sum_app_opens  no_of_days  \
# 0  00b74e27ad1cbb2ded8e907fcc49eaaf           6839         477
# 1  024610702baf540af5637873cd1534e9          26280        1197
#
#    nrOfConversations  longestConversation  longestConversationInDays  \
# 0                739                  133                        684
# 1                464                   36                        622
#
#    averageConversationLength  averageConversationLengthInDays  \
# 0                       8.56                            10.24
# 1                       4.50                             3.97
#
#    medianConversationLength  medianConversationLengthInDays  \
# 0                         3                        0.081134
# 1                         2                        0.000069
#
#    nrOfOneMessageConversations  percentOfOneMessageConversations  \
# 0                          226                             30.58
# 1                           56                             12.07
#
#    nrOfGhostingsAfterInitialMessage  no_of_matches  no_of_msgs_sent  \
# 0                                66           3408             3360
# 1                                16            888             2088
#
#    no_of_msgs_received  swipe_likes  swipe_passes   birthDate  ageFilterMin  \
# 0                 3261        23341         24229  1976-01-01            21
# 1                 1509        45068         49559  1997-07-04            18
#
#    ageFilterMax   cityName country  createDate  \
# 0            35  Trondheim  Norway  2016-01-01
# 1            29   Richmond     USA  2016-07-12
#
#                                   education gender interestedIn  instagram  \
# 0  Has high school and/or college education      M            F      False
# 1  Has high school and/or college education      M            F      False
#
#    spotify jobTitle  user_age
# 0    False  unknown        40
# 1    False  unknown        19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 31 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   _id                               1209 non-null   object
#  1   sum_app_opens                     1209 non-null   int64
#  2   no_of_days                        1209 non-null   int64
#  3   nrOfConversations                 1209 non-null   int64
#  4   longestConversation               1209 non-null   int64
#  5   longestConversationInDays         1209 non-null   int64
#  6   averageConversationLength         1209 non-null   float64
#  7   averageConversationLengthInDays   1209 non-null   float64
#  8   medianConversationLength          1209 non-null   int64
#  9   medianConversationLengthInDays    1209 non-null   float64
#  10  nrOfOneMessageConversations       1209 non-null   int64
#  11  percentOfOneMessageConversations  1209 non-null   float64
#  12  nrOfGhostingsAfterInitialMessage  1209 non-null   int64
#  13  no_of_matches                     1209 non-null   int64
#  14  no_of_msgs_sent                   1209 non-null   int64
#  15  no_of_msgs_received               1209 non-null   int64
#  16  swipe_likes                       1209 non-null   int64
#  17  swipe_passes                      1209 non-null   int64
#  18  birthDate                         1209 non-null   object
#  19  ageFilterMin                      1209 non-null   int64
#  20  ageFilterMax                      1209 non-null   int64
#  21  cityName                          1209 non-null   object
#  22  country                           1209 non-null   object
#  23  createDate                        1209 non-null   object
#  24  education                         1209 non-null   object
#  25  gender                            1209 non-null   object
#  26  interestedIn                      1209 non-null   object
#  27  instagram                         1209 non-null   bool
#  28  spotify                           1209 non-null   bool
#  29  jobTitle                          1209 non-null   object
#  30  user_age                          1209 non-null   int64
# dtypes: bool(2), float64(4), int64(16), object(9)
# memory usage: 276.4+ KB

# %%
def exploracion(df):
    df_info = pd.DataFrame()
    df_info["% nulos"] = round(df.isna().sum()/df.shape[0]*100, 2).astype(str)+"%"
    df_info["% no_nulos"] = round(df.notna().sum()/df.shape[0]*100, 2).astype(str)+"%"
    df_info["tipo_dato"] = df.dtypes
    df_info["num_valores_unicos"] = df.nunique()
    print(f"""El DataFrame tiene {df.shape[0]} filas y {df.shape[1]} columnas.
Tiene {df.duplicated().sum()} datos duplicados, lo que supone un porcentaje de {round(df.duplicated().sum()/df.shape[0], 2)}% de los datos.
Hay {len(list(df_info[(df_info["% nulos"] != "0.0%")].index))} columnas con datos nulos, y son:
{list(df_info[(df_info["% nulos"] != "0.0%")].index)}
y sin nulos hay {len(list(df_info[(df_info["% nulos"] == "0.0%")].index))} columnas y son:
{list(df_info[(df_info["% nulos"] == "0.0%")].index)}
A continuación tienes un detalle sobre los datos nulos y los tipos y número de datos:""")
    display(df_info.head())
    print("Principales estadísticos de las columnas categóricas:")
    display(df.describe(include="O").T)
    print("Principales estadísticos de las columnas numéricas:")
    display(df.describe(exclude="O").T)
    return df_info

# %%
exploracion(df)
# Out:
# El DataFrame tiene 1209 filas y 31 columnas.
# Tiene 0 datos duplicados, lo que supone un porcentaje de 0.0% de los datos.
# Hay 0 columnas con datos nulos, y son:
# []
# y sin nulos hay 31 columnas y son:
# ['_id', 'sum_app_opens', 'no_of_days', 'nrOfConversations', 'longestConversation', 'longestConversationInDays', 'averageConversationLength', 'averageConversationLengthInDays', 'medianConversationLength', 'medianConversationLengthInDays', 'nrOfOneMessageConversations', 'percentOfOneMessageConversations', 'nrOfGhostingsAfterInitialMessage', 'no_of_matches', 'no_of_msgs_sent', 'no_of_msgs_received', 'swipe_likes', 'swipe_passes', 'birthDate', 'ageFilterMin', 'ageFilterMax', 'cityName', 'country', 'createDate', 'education', 'gender', 'interestedIn', 'instagram', 'spotify', 'jobTitle', 'user_age']
# A continuación tienes un detalle sobre los datos nulos y los tipos y número de datos:
#                     % nulos % no_nulos tipo_dato  num_valores_unicos
# _id                    0.0%     100.0%    object                1209
# sum_app_opens          0.0%     100.0%     int64                 927
# no_of_days             0.0%     100.0%     int64                 595
# nrOfConversations      0.0%     100.0%     int64                 449
# longestConversation    0.0%     100.0%     int64                 356
# Principales estadísticos de las columnas categóricas:
#              count unique                                      top  freq
# _id           1209   1209         00b74e27ad1cbb2ded8e907fcc49eaaf     1
# birthDate     1209   1071                               2000-07-09     4
# cityName      1209    444                                  unknown   480
# country       1209     57                                  unknown   481
# createDate    1209    879                               2021-08-06     5
# education     1209      2  Has no high school or college education  1000
# gender        1209      2                                        M  1059
# interestedIn  1209      3                                        F  1018
# jobTitle      1209    314                                  unknown   757
# Principales estadísticos de las columnas numéricas:
#                                    count unique    top freq          mean  \
# sum_app_opens                     1209.0    NaN    NaN  NaN   4593.923077
# no_of_days                        1209.0    NaN    NaN  NaN    327.335815
# nrOfConversations                 1209.0    NaN    NaN  NaN    241.918114
# longestConversation               1209.0    NaN    NaN  NaN     139.11828
# longestConversationInDays         1209.0    NaN    NaN  NaN    166.403639
# averageConversationLength         1209.0    NaN    NaN  NaN      9.809123
# averageConversationLengthInDays   1209.0    NaN    NaN  NaN       3.66488
# medianConversationLength          1209.0    NaN    NaN  NaN      4.275434
# medianConversationLengthInDays    1209.0    NaN    NaN  NaN      0.524231
# nrOfOneMessageConversations       1209.0    NaN    NaN  NaN     75.727047
# percentOfOneMessageConversations  1209.0    NaN    NaN  NaN     30.972862
# nrOfGhostingsAfterInitialMessage  1209.0    NaN    NaN  NaN     29.519438
# no_of_matches                     1209.0    NaN    NaN  NaN    542.214227
# no_of_msgs_sent                   1209.0    NaN    NaN  NaN   1884.516956
# no_of_msgs_received               1209.0    NaN    NaN  NaN    1793.08354
# swipe_likes                       1209.0    NaN    NaN  NaN  14643.898263
# swipe_passes                      1209.0    NaN    NaN  NaN  26399.340778
# ageFilterMin                      1209.0    NaN    NaN  NaN     20.467328
# ageFilterMax                      1209.0    NaN    NaN  NaN     95.219189
# instagram                           1209      2  False  942           NaN
# spotify                             1209      2  False  752           NaN
# user_age                          1209.0    NaN    NaN  NaN      24.39206
#
#                                            std   min     25%       50%  \
# sum_app_opens                      8501.985991   0.0   236.0    1916.0
# no_of_days                          420.853107   0.0    20.0     164.0
# nrOfConversations                   674.592881   0.0    20.0      67.0
# longestConversation                  226.28775   0.0    27.0      69.0
# longestConversationInDays           323.848949   0.0     7.0      32.0
# averageConversationLength            18.071807   0.0    3.66      6.41
# averageConversationLengthInDays       5.915688   0.0    0.76      1.83
# medianConversationLength             27.997121   0.0     1.0       2.0
# medianConversationLengthInDays        5.939479   0.0     0.0  0.006759
# nrOfOneMessageConversations         230.038166   0.0     5.0      19.0
# percentOfOneMessageConversations     18.310761   0.0   19.05     30.21
# nrOfGhostingsAfterInitialMessage    149.191069   0.0     0.0       3.0
# no_of_matches                      1515.892456   0.0     9.0     108.0
# no_of_msgs_sent                     4425.48433   0.0   123.0     520.0
# no_of_msgs_received                4219.296682   0.0   117.0     499.0
# swipe_likes                       37623.882473   0.0   317.0    3484.0
# swipe_passes                      49869.115465   0.0  1146.0    8878.0
# ageFilterMin                          3.340123  18.0    18.0      19.0
# ageFilterMax                        239.492885  18.0    26.0      30.0
# instagram                                  NaN   NaN     NaN       NaN
# spotify                                    NaN   NaN     NaN       NaN
# user_age                              7.359173   0.0    20.0      23.0
#
#                                        75%        max
# sum_app_opens                       5445.0    92628.0
# no_of_days                           455.0     2319.0
# nrOfConversations                    226.0    12642.0
# longestConversation                  161.0     2264.0
# longestConversationInDays            153.0     2284.0
# averageConversationLength            10.82      461.0
# averageConversationLengthInDays       4.02      92.71
# medianConversationLength               3.0      920.0
# medianConversationLengthInDays    0.092465  185.19294
# nrOfOneMessageConversations           65.0     4807.0
# percentOfOneMessageConversations     41.18      100.0
# nrOfGhostingsAfterInitialMessage      15.0     4408.0
# no_of_matches                        468.0    23758.0
# no_of_msgs_sent                     1782.0    61881.0
# no_of_msgs_received                 1760.0    56173.0
# swipe_likes                        13887.0   705781.0
# swipe_passes                       28210.0   550653.0
# ageFilterMin                          22.0       46.0
# ageFilterMax                          38.0     1000.0
# instagram                              NaN        NaN
# spotify                                NaN        NaN
# user_age                              27.0      137.0
#                                  % nulos % no_nulos tipo_dato  \
# _id                                 0.0%     100.0%    object
# sum_app_opens                       0.0%     100.0%     int64
# no_of_days                          0.0%     100.0%     int64
# nrOfConversations                   0.0%     100.0%     int64
# longestConversation                 0.0%     100.0%     int64
# longestConversationInDays           0.0%     100.0%     int64
# averageConversationLength           0.0%     100.0%   float64
# averageConversationLengthInDays     0.0%     100.0%   float64
# medianConversationLength            0.0%     100.0%     int64
# medianConversationLengthInDays      0.0%     100.0%   float64
# nrOfOneMessageConversations         0.0%     100.0%     int64
# percentOfOneMessageConversations    0.0%     100.0%   float64
# nrOfGhostingsAfterInitialMessage    0.0%     100.0%     int64
# no_of_matches                       0.0%     100.0%     int64
# no_of_msgs_sent                     0.0%     100.0%     int64
# no_of_msgs_received                 0.0%     100.0%     int64
# swipe_likes                         0.0%     100.0%     int64
# swipe_passes                        0.0%     100.0%     int64
# birthDate                           0.0%     100.0%    object
# ageFilterMin                        0.0%     100.0%     int64
# ageFilterMax                        0.0%     100.0%     int64
# cityName                            0.0%     100.0%    object
# country                             0.0%     100.0%    object
# createDate                          0.0%     100.0%    object
# education                           0.0%     100.0%    object
# gender                              0.0%     100.0%    object
# interestedIn                        0.0%     100.0%    object
# instagram                           0.0%     100.0%      bool
# spotify                             0.0%     100.0%      bool
# jobTitle                            0.0%     100.0%    object
# user_age                            0.0%     100.0%     int64
#
#                                   num_valores_unicos
# _id                                             1209
# sum_app_opens                                    927
# no_of_days                                       595
# nrOfConversations                                449
# longestConversation                              356
# longestConversationInDays                        394
# averageConversationLength                        826
# averageConversationLengthInDays                  605
# medianConversationLength                          35
# medianConversationLengthInDays                   729
# nrOfOneMessageConversations                      246
# percentOfOneMessageConversations                 745
# nrOfGhostingsAfterInitialMessage                 157
# no_of_matches                                    563
# no_of_msgs_sent                                  867
# no_of_msgs_received                              868
# swipe_likes                                      952
# swipe_passes                                     969
# birthDate                                       1071
# ageFilterMin                                      20
# ageFilterMax                                      46
# cityName                                         444
# country                                           57
# createDate                                       879
# education                                          2
# gender                                             2
# interestedIn                                       3
# instagram                                          2
# spotify                                            2
# jobTitle                                         314
# user_age                                          39
